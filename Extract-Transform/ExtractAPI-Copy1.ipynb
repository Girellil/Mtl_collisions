# %%
import pandas as pd
import requests
from io import StringIO
from pymongo import MongoClient

# %%
mtlcollisions_csv = "https://donnees.montreal.ca/dataset/cd722e22-376b-4b89-9bc2-7c7ab317ef6b/resource/05deae93-d9fc-4acb-9779-e0942b5e962f/download/collisions_routieres.csv"

# %%
def download_csv(url):
    response = requests.get(url)
    # Raise an exception for bad status codes
    response.raise_for_status()  
    return response.text

# %%
# Dowload data
csv_data = download_csv(mtlcollisions_csv)

# Read CSV data into pandas DataFrame
mtlcollisions_df = pd.read_csv(StringIO(csv_data))

# %%
# Now 'df' contains your CSV data as a pandas DataFrame
print(mtlcollisions_df.dtypes)
# Out:
# NO_SEQ_COLL         object
# JR_SEMN_ACCDN       object
# DT_ACCDN            object
# CD_MUNCP           float64
# NO_CIVIQ_ACCDN     float64
#                     ...
# LOC_COTE_PD          int64
# LOC_DETACHEE        object
# LOC_IMPRECISION     object
# LOC_LONG           float64
# LOC_LAT            float64
# Length: 68, dtype: object

# %%
mtlcollisions_df.columns
# Out:
# Index(['NO_SEQ_COLL', 'JR_SEMN_ACCDN', 'DT_ACCDN', 'CD_MUNCP',
#        'NO_CIVIQ_ACCDN', 'SFX_NO_CIVIQ_ACCDN', 'BORNE_KM_ACCDN', 'RUE_ACCDN',
#        'TP_REPRR_ACCDN', 'ACCDN_PRES_DE', 'NB_METRE_DIST_ACCD',
#        'CD_GENRE_ACCDN', 'CD_SIT_PRTCE_ACCDN', 'CD_ETAT_SURFC', 'CD_ECLRM',
#        'CD_ENVRN_ACCDN', 'NO_ROUTE', 'CD_CATEG_ROUTE', 'CD_ETAT_CHASS',
#        'CD_ASPCT_ROUTE', 'CD_LOCLN_ACCDN', 'CD_POSI_ACCDN', 'CD_CONFG_ROUTE',
#        'CD_ZON_TRAVX_ROUTR', 'CD_PNT_CDRNL_ROUTE', 'CD_PNT_CDRNL_REPRR',
#        'CD_COND_METEO', 'NB_VEH_IMPLIQUES_ACCDN', 'NB_MORTS',
#        'NB_BLESSES_GRAVES', 'NB_BLESSES_LEGERS', 'HEURE_ACCDN', 'AN',
#        'NB_VICTIMES_TOTAL', 'GRAVITE', 'REG_ADM', 'MRC',
#        'nb_automobile_camion_leger', 'nb_camionLourd_tractRoutier',
#        'nb_outil_equipement', 'nb_tous_autobus_minibus', 'nb_bicyclette',
#        'nb_cyclomoteur', 'nb_motocyclette', 'nb_taxi', 'nb_urgence',
#        'nb_motoneige', 'nb_VHR', 'nb_autres_types', 'nb_veh_non_precise',
#        'NB_DECES_PIETON', 'NB_BLESSES_PIETON', 'NB_VICTIMES_PIETON',
#        'NB_DECES_MOTO', 'NB_BLESSES_MOTO', 'NB_VICTIMES_MOTO', 'NB_DECES_VELO',
#        'NB_BLESSES_VELO', 'NB_VICTIMES_VELO', 'VITESSE_AUTOR', 'LOC_X',
#        'LOC_Y', 'LOC_COTE_QD', 'LOC_COTE_PD', 'LOC_DETACHEE',
#        'LOC_IMPRECISION', 'LOC_LONG', 'LOC_LAT'],
#       dtype='object')

# %%
mtlcollisions_df.head(5)
# Out:
#            NO_SEQ_COLL JR_SEMN_ACCDN    DT_ACCDN  CD_MUNCP  NO_CIVIQ_ACCDN  \
# 0      SPVM _ 2012 _ 1            ME  2012/02/01   66102.0          3501.0
# 1     SPVM _ 2012 _ 10            MA  2012/01/03   66023.0             NaN
# 2    SPVM _ 2012 _ 100            VE  2012/02/24   66023.0             NaN
# 3   SPVM _ 2012 _ 1000            JE  2012/10/11   66142.0         11800.0
# 4  SPVM _ 2012 _ 10000            DI  2012/04/22   66023.0            38.0
#
#   SFX_NO_CIVIQ_ACCDN  BORNE_KM_ACCDN          RUE_ACCDN  TP_REPRR_ACCDN  \
# 0                NaN             NaN         ST CHARLES             2.0
# 1                NaN             NaN  TERR VILLE DE MTL             NaN
# 2                NaN             NaN     JACQUES BIZARD             1.0
# 3                NaN             NaN       BD SALABERRY             NaN
# 4                NaN             NaN     PL DU COMMERCE             NaN
#
#   ACCDN_PRES_DE  ...  NB_VICTIMES_VELO  VITESSE_AUTOR         LOC_X  \
# 0          STAT  ...                 0            NaN  276517.37950
# 1           NaN  ...                 0            NaN  275209.46185
# 2      CHERRIER  ...                 0           50.0  275759.07900
# 3           NaN  ...                 0            NaN  280970.09315
# 4           NaN  ...                 0            NaN  301391.47638
#
#           LOC_Y  LOC_COTE_QD  LOC_COTE_PD  LOC_DETACHEE  LOC_IMPRECISION  \
# 0  5.035127e+06            A            3             O                N
# 1  5.038619e+06            B            4             N                N
# 2  5.039027e+06            A            1             N                O
# 3  5.038348e+06            A            1             O                N
# 4  5.036357e+06            A            1             O                N
#
#     LOC_LONG    LOC_LAT
# 0 -73.861616  45.455505
# 1 -73.878549  45.486871
# 2 -73.871542  45.490564
# 3 -73.804841  45.484648
# 4 -73.543590  45.467136
#
# [5 rows x 68 columns]

# %%
mtlcollisions_df_m = mtlcollisions_df.copy()

# %%
mtlcollisions_df_m["DT_ACCDN"] = pd.to_datetime(mtlcollisions_df_m["DT_ACCDN"], format='%Y/%m/%d')
mtlcollisions_df_m.sort_values(by='DT_ACCDN', ascending=False)
mtlcollisions_df_1821 = mtlcollisions_df_m.loc[mtlcollisions_df_m["DT_ACCDN"] > '2018-01-01']
mtlcollisions_df_1821
# Out:
#                 NO_SEQ_COLL JR_SEMN_ACCDN   DT_ACCDN  CD_MUNCP  \
# 149972      SPVM _ 2018 _ 1            MA 2018-01-02   66023.0
# 149973     SPVM _ 2018 _ 10            MA 2018-01-09   66023.0
# 149974    SPVM _ 2018 _ 100            JE 2018-03-15   66023.0
# 149975   SPVM _ 2018 _ 1000            LU 2018-04-23   66087.0
# 149976  SPVM _ 2018 _ 10000            SA 2018-09-08   66023.0
# ...                     ...           ...        ...       ...
# 218267   SPVM _ 2021 _ 9995            ME 2021-07-28   66023.0
# 218268   SPVM _ 2021 _ 9996            ME 2021-07-28   66023.0
# 218269   SPVM _ 2021 _ 9997            LU 2021-07-26   66023.0
# 218270   SPVM _ 2021 _ 9998            ME 2021-07-28   66023.0
# 218271   SPVM _ 2021 _ 9999            ME 2021-07-28   66023.0
#
#         NO_CIVIQ_ACCDN SFX_NO_CIVIQ_ACCDN  BORNE_KM_ACCDN  \
# 149972             NaN                NaN             NaN
# 149973             NaN                NaN             NaN
# 149974             NaN                NaN             NaN
# 149975           585.0                NaN             NaN
# 149976             NaN                NaN             NaN
# ...                ...                ...             ...
# 218267             NaN                NaN             NaN
# 218268             NaN                NaN             NaN
# 218269          5507.0                NaN             NaN
# 218270             NaN                NaN             NaN
# 218271          4158.0                NaN             NaN
#
#                                RUE_ACCDN  TP_REPRR_ACCDN  \
# 149972   BD PIERREFONDS BD JACQUES BIZAR             NaN
# 149973                    BD PIERREFONDS             1.0
# 149974                        BD GOUIN O             1.0
# 149975                           MELOCHE             NaN
# 149976                               NaN             1.0
# ...                                  ...             ...
# 218267                      PARC DU AVEN             1.0
# 218268  COTE-SAINTE-CATHERINE DE LA CHEM             1.0
# 218269                   SAINT-ANDRE RUE             NaN
# 218270                      CHAMBORD RUE             1.0
# 218271                 HENRI-JULIEN AVEN             NaN
#
#                ACCDN_PRES_DE  ...  NB_VICTIMES_VELO  VITESSE_AUTOR  \
# 149972                   NaN  ...                 0            NaN
# 149973               DRESDEN  ...                 0           50.0
# 149974           BD PITFIELD  ...                 0            NaN
# 149975                   NaN  ...                 0           50.0
# 149976   HOCHELAGA ET VIMONT  ...                 0           50.0
# ...                      ...  ...               ...            ...
# 218267            BERUBE RUE  ...                 0           40.0
# 218268  MONT-ROYAL DU O AVEN  ...                 0           50.0
# 218269                   NaN  ...                 0           30.0
# 218270  MONT-ROYAL DU E AVEN  ...                 1           30.0
# 218271                   NaN  ...                 0           30.0
#
#                LOC_X         LOC_Y  LOC_COTE_QD  LOC_COTE_PD  LOC_DETACHEE  \
# 149972  276486.60700  5.038090e+06            A            1             N
# 149973  279219.92101  5.040510e+06            A            1             N
# 149974  284478.84100  5.040916e+06            A            1             N
# 149975  287037.75050  5.034863e+06            A            1             N
# 149976  301540.79700  5.047004e+06            A            1             N
# ...              ...           ...          ...          ...           ...
# 218267  297702.11400  5.041951e+06            A            1             N
# 218268  297747.89500  5.041766e+06            A            2             N
# 218269  297554.60015  5.043556e+06            A            1             N
# 218270  298745.43500  5.043323e+06            A            1             N
# 218271  298645.45450  5.042302e+06            A            1             N
#
#         LOC_IMPRECISION   LOC_LONG    LOC_LAT
# 149972                N -73.862180  45.482162
# 149973                N -73.827343  45.504040
# 149974                O -73.760063  45.507868
# 149975                N -73.727096  45.453469
# 149976                N -73.541751  45.562940
# ...                 ...        ...        ...
# 218267                N -73.590852  45.517438
# 218268                N -73.590263  45.515779
# 218269                N -73.592764  45.531882
# 218270                N -73.577514  45.529801
# 218271                N -73.578781  45.520607
#
# [68246 rows x 68 columns]

# %%
# MongoDB Atlas connection details
connection_string = "mongodb+srv://lucasagirelli:patoyelsa@girellil.nqz2prr.mongodb.net/"
database_name = 'mtl_collisions'

# Connect to MongoDB Atlas
client = MongoClient(connection_string)
db = client[database_name]
collection_name = "collisions_db"
    
if collection_name not in db.list_collection_names():
    db.create_collection(collection_name)

collection = db[collection_name]

# Convert dataframe to dictionary format and insert into MongoDB
data_dict = mtlcollisions_df_1821.to_dict(orient='records')
collection.insert_many(data_dict)
# Out:
# ---------------------------------------------------------------------------
# ZeroReturnError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1020, in Connection.receive_message(self, request_id)
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#
# File ~\anaconda3\Lib\site-packages\pymongo\network.py:257, in receive_message(conn, request_id, max_message_size)
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#
# File ~\anaconda3\Lib\site-packages\pymongo\network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#
# File ~\anaconda3\Lib\site-packages\pymongo\pyopenssl_context.py:155, in _sslConn.recv_into(self, *args, **kwargs)
#     154 try:
# --> 155     return self._call(super().recv_into, *args, **kwargs)
#     156 except _SSL.SysCallError as exc:
#     157     # Suppress ragged EOFs to match the stdlib.
#
# File ~\anaconda3\Lib\site-packages\pymongo\pyopenssl_context.py:120, in _sslConn._call(self, call, *args, **kwargs)
#     119 try:
# --> 120     return call(*args, **kwargs)
#     121 except BLOCKING_IO_ERRORS as exc:
#     122     # Check for closed socket.
#
# File ~\anaconda3\Lib\site-packages\OpenSSL\SSL.py:2108, in Connection.recv_into(self, buffer, nbytes, flags)
#    2107     result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 2108 self._raise_ssl_error(self._ssl, result)
#    2110 # This strange line is all to avoid a memory copy. The buffer protocol
#    2111 # should allow us to assign a CFFI buffer to the LHS of this line, but
#    2112 # on CPython 3.3+ that segfaults. As a workaround, we can temporarily
#    2113 # wrap it in a memoryview.
#
# File ~\anaconda3\Lib\site-packages\OpenSSL\SSL.py:1814, in Connection._raise_ssl_error(self, ssl, result)
#    1813 elif error == _lib.SSL_ERROR_ZERO_RETURN:
# -> 1814     raise ZeroReturnError()
#    1815 elif error == _lib.SSL_ERROR_WANT_X509_LOOKUP:
#    1816     # TODO: This is untested.
#
# ZeroReturnError:
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# Cell In[26], line 17
#      15 # Convert dataframe to dictionary format and insert into MongoDB
#      16 data_dict = mtlcollisions_df_1821.to_dict(orient='records')
# ---> 17 collection.insert_many(data_dict)
#
# File ~\anaconda3\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# --> 755 blk.execute(write_concern, session=session)
#     756 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:576, in _Bulk.execute(self, write_concern, session)
#     574         return None
#     575 else:
# --> 576     return self.execute_command(generator, write_concern, session)
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:443, in _Bulk.execute_command(self, generator, write_concern, session)
#     432     self._execute_command(
#     433         generator,
#     434         write_concern,
#    (...)
#     439         full_result,
#     440     )
#     442 client = self.collection.database.client
# --> 443 client._retryable_write(self.is_retryable, retryable_bulk, session, bulk=self)
#     445 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     446     _raise_bulk_write_error(full_result)
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File ~\anaconda3\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~\anaconda3\Lib\site-packages\pymongo\mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:432, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     429 def retryable_bulk(
#     430     session: Optional[ClientSession], conn: Connection, retryable: bool
#     431 ) -> None:
# --> 432     self._execute_command(
#     433         generator,
#     434         write_concern,
#     435         session,
#     436         conn,
#     437         op_id,
#     438         retryable,
#     439         full_result,
#     440     )
#
# File ~\anaconda3\Lib\site-packages\pymongo\bulk.py:378, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     376 # Run as many ops as possible in one command.
#     377 if write_concern.acknowledged:
# --> 378     result, to_send = bwc.execute(cmd, ops, client)
#     380     # Retryable writeConcernErrors halt the execution of this run.
#     381     wce = result.get("writeConcernError", {})
#
# File ~\anaconda3\Lib\site-packages\pymongo\message.py:964, in _BulkWriteContext.execute(self, cmd, docs, client)
#     960 def execute(
#     961     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]], client: MongoClient
#     962 ) -> tuple[Mapping[str, Any], list[Mapping[str, Any]]]:
#     963     request_id, msg, to_send = self.__batch_command(cmd, docs)
# --> 964     result = self.write_command(cmd, request_id, msg, to_send)
#     965     client._process_response(result, self.session)
#     966     return result, to_send
#
# File ~\anaconda3\Lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~\anaconda3\Lib\site-packages\pymongo\message.py:1058, in _BulkWriteContext.write_command(self, cmd, request_id, msg, docs)
#    1056     start = datetime.datetime.now()
#    1057 try:
# -> 1058     reply = self.conn.write_command(request_id, msg, self.codec)
#    1059     if self.publish:
#    1060         duration = (datetime.datetime.now() - start) + duration
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1056, in Connection.write_command(self, request_id, msg, codec_options)
#    1047 """Send "insert" etc. command, returning response as a dict.
#    1048
#    1049 Can raise ConnectionFailure or OperationFailure.
#    (...)
#    1053   - `msg`: bytes, the command message.
#    1054 """
#    1055 self.send_message(msg, 0)
# -> 1056 reply = self.receive_message(request_id)
#    1057 result = reply.command_response(codec_options)
#    1059 # Raises NotPrimaryError or OperationFailure.
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:1171, in Connection._raise_connection_failure(self, error)
#    1169 if isinstance(error, (IOError, OSError, SSLError)):
#    1170     details = _get_timeout_details(self.opts)
# -> 1171     _raise_connection_failure(self.address, error, timeout_details=details)
#    1172 else:
#    1173     raise
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:411, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     409     raise NetworkTimeout(msg) from error
#     410 else:
# --> 411     raise AutoReconnect(msg) from error
#
# AutoReconnect: ac-78l6qh3-shard-00-01.nqz2prr.mongodb.net:27017:  (configured timeouts: connectTimeoutMS: 20000.0ms)
