# %%
# %run Transform.ipynb
# Out:
# NO_SEQ_COLL                     object
# JR_SEMN_ACCDN                   object
# DT_ACCDN                        object
# CD_MUNCP                       float64
# NO_CIVIQ_ACCDN                 float64
# SFX_NO_CIVIQ_ACCDN              object
# BORNE_KM_ACCDN                 float64
# RUE_ACCDN                       object
# TP_REPRR_ACCDN                 float64
# ACCDN_PRES_DE                   object
# NB_METRE_DIST_ACCD             float64
# CD_GENRE_ACCDN                 float64
# CD_SIT_PRTCE_ACCDN             float64
# CD_ETAT_SURFC                  float64
# CD_ECLRM                       float64
# CD_ENVRN_ACCDN                 float64
# NO_ROUTE                       float64
# CD_CATEG_ROUTE                 float64
# CD_ETAT_CHASS                  float64
# CD_ASPCT_ROUTE                 float64
# CD_LOCLN_ACCDN                 float64
# CD_POSI_ACCDN                  float64
# CD_CONFG_ROUTE                 float64
# CD_ZON_TRAVX_ROUTR             float64
# CD_PNT_CDRNL_ROUTE              object
# CD_PNT_CDRNL_REPRR              object
# CD_COND_METEO                  float64
# NB_VEH_IMPLIQUES_ACCDN           int64
# NB_MORTS                         int64
# NB_BLESSES_GRAVES                int64
# NB_BLESSES_LEGERS                int64
# HEURE_ACCDN                     object
# AN                               int64
# NB_VICTIMES_TOTAL                int64
# GRAVITE                         object
# REG_ADM                         object
# MRC                             object
# nb_automobile_camion_leger       int64
# nb_camionLourd_tractRoutier      int64
# nb_outil_equipement              int64
# nb_tous_autobus_minibus          int64
# nb_bicyclette                    int64
# nb_cyclomoteur                   int64
# nb_motocyclette                  int64
# nb_taxi                          int64
# nb_urgence                       int64
# nb_motoneige                     int64
# nb_VHR                           int64
# nb_autres_types                  int64
# nb_veh_non_precise               int64
# NB_DECES_PIETON                  int64
# NB_BLESSES_PIETON                int64
# NB_VICTIMES_PIETON               int64
# NB_DECES_MOTO                    int64
# NB_BLESSES_MOTO                  int64
# NB_VICTIMES_MOTO                 int64
# NB_DECES_VELO                    int64
# NB_BLESSES_VELO                  int64
# NB_VICTIMES_VELO                 int64
# VITESSE_AUTOR                  float64
# LOC_X                          float64
# LOC_Y                          float64
# LOC_COTE_QD                     object
# LOC_COTE_PD                      int64
# LOC_DETACHEE                    object
# LOC_IMPRECISION                 object
# LOC_LONG                       float64
# LOC_LAT                        float64
# dtype: object
# 218272
# DT_ACCDN       datetime64[ns]
# HEURE_ACCDN            object
# init_time              object
# final_time             object
# dtype: object

# %%
mtlcollisions_df_filtered.head(5)
# Out:
#                 NO_SEQ_COLL JR_SEMN_ACCDN   DT_ACCDN  CD_MUNCP  \
# 149972      SPVM _ 2018 _ 1            MA 2018-01-02   66023.0
# 149973     SPVM _ 2018 _ 10            MA 2018-01-09   66023.0
# 149974    SPVM _ 2018 _ 100            JE 2018-03-15   66023.0
# 149975   SPVM _ 2018 _ 1000            LU 2018-04-23   66087.0
# 149976  SPVM _ 2018 _ 10000            SA 2018-09-08   66023.0
#
#         NO_CIVIQ_ACCDN                        RUE_ACCDN  CD_ETAT_SURFC  \
# 149972             NaN  BD PIERREFONDS BD JACQUES BIZAR           11.0
# 149973             NaN                   BD PIERREFONDS           16.0
# 149974             NaN                       BD GOUIN O           11.0
# 149975           585.0                          MELOCHE           11.0
# 149976             NaN                              NaN           11.0
#
#         CD_ECLRM  CD_ENVRN_ACCDN  CD_LOCLN_ACCDN  CD_ZON_TRAVX_ROUTR  \
# 149972       3.0             3.0            32.0                 NaN
# 149973       1.0             2.0            32.0                 NaN
# 149974       1.0             3.0             NaN                 NaN
# 149975       1.0             4.0            34.0                 NaN
# 149976       1.0             3.0            32.0                 NaN
#
#         NB_VEH_IMPLIQUES_ACCDN  NB_MORTS  NB_BLESSES_GRAVES  \
# 149972                       2         0                  0
# 149973                       1         0                  0
# 149974                       2         0                  0
# 149975                       2         0                  0
# 149976                       2         0                  0
#
#         NB_BLESSES_LEGERS        HEURE_ACCDN    AN  NB_VICTIMES_TOTAL  \
# 149972                  0  19:00:00-19:59:00  2018                  0
# 149973                  0  12:00:00-12:59:00  2018                  0
# 149974                  0  16:00:00-16:59:00  2018                  0
# 149975                  0  15:00:00-15:59:00  2018                  0
# 149976                  0  08:00:00-08:59:00  2018                  0
#
#                                                   GRAVITE  \
# 149972                       Dommages matériels seulement
# 149973                       Dommages matériels seulement
# 149974  Dommages matériels inférieurs au seuil de rapp...
# 149975                       Dommages matériels seulement
# 149976                       Dommages matériels seulement
#
#         nb_automobile_camion_leger  nb_camionLourd_tractRoutier  \
# 149972                           1                            0
# 149973                           1                            0
# 149974                           1                            0
# 149975                           1                            1
# 149976                           2                            0
#
#         nb_outil_equipement  nb_tous_autobus_minibus  nb_bicyclette  \
# 149972                    0                        0              0
# 149973                    0                        0              0
# 149974                    0                        1              0
# 149975                    0                        0              0
# 149976                    0                        0              0
#
#         nb_cyclomoteur  nb_motocyclette  nb_taxi  nb_urgence  nb_motoneige  \
# 149972               0                0        0           0             0
# 149973               0                0        0           0             0
# 149974               0                0        0           0             0
# 149975               0                0        0           0             0
# 149976               0                0        0           0             0
#
#         nb_VHR  nb_autres_types  nb_veh_non_precise  NB_DECES_PIETON  \
# 149972       0                0                   1                0
# 149973       0                0                   0                0
# 149974       0                0                   0                0
# 149975       0                0                   0                0
# 149976       0                0                   0                0
#
#         NB_BLESSES_PIETON  NB_VICTIMES_PIETON  NB_DECES_MOTO  NB_BLESSES_MOTO  \
# 149972                  0                   0              0                0
# 149973                  0                   0              0                0
# 149974                  0                   0              0                0
# 149975                  0                   0              0                0
# 149976                  0                   0              0                0
#
#         NB_VICTIMES_MOTO  NB_DECES_VELO  NB_BLESSES_VELO  NB_VICTIMES_VELO  \
# 149972                 0              0                0                 0
# 149973                 0              0                0                 0
# 149974                 0              0                0                 0
# 149975                 0              0                0                 0
# 149976                 0              0                0                 0
#
#         VITESSE_AUTOR         LOC_X        LOC_Y LOC_IMPRECISION   LOC_LONG  \
# 149972            NaN  276486.60700  5038090.126               N -73.862180
# 149973           50.0  279219.92101  5040509.731               N -73.827343
# 149974            NaN  284478.84100  5040915.926               O -73.760063
# 149975           50.0  287037.75050  5034862.750               N -73.727096
# 149976           50.0  301540.79700  5047004.083               N -73.541751
#
#           LOC_LAT init_time final_time
# 149972  45.482162  19:00:00   19:59:00
# 149973  45.504040  12:00:00   12:59:00
# 149974  45.507868  16:00:00   16:59:00
# 149975  45.453469  15:00:00   15:59:00
# 149976  45.562940  08:00:00   08:59:00

# %%
len(mtlcollisions_df_filtered)
# Out:
# 68246

# %%
# Import the credentials
import os
import sys

#backup current dir. Optional
original_dir = os.getcwd()

# Change the working directory to the root directory
os.chdir('..')
# Add the root directory to the system path
sys.path.append('.')
# Import password
from db_credentials import mongo_pass
#reset dir
os.chdir(original_dir)

# %%
from pymongo import MongoClient

# %%
# MongoDB Atlas connection details
connection_string = "mongodb+srv://lucasagirelli:" + mongo_pass + "@girellil.nqz2prr.mongodb.net/"
database_name = 'collisions_db'

# Connect to MongoDB Atlas
client = MongoClient(connection_string)
db = client[database_name]
collection_name = "mtl_collisions"
    
#if collection_name not in db.list_collection_names():
#    db.create_collection(collection_name)

collection = db[collection_name]

# Convert dataframe to dictionary format and insert into MongoDB
data_dict = mtlcollisions_df_filtered.to_dict(orient='records')
collection.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('66a2aeb7eed78a79fc781634'), ObjectId('66a2aeb7eed78a79fc781635'), ObjectId('66a2aeb7eed78a79fc781636'), ObjectId('66a2aeb7eed78a79fc781637'), ObjectId('66a2aeb7eed78a79fc781638'), ObjectId('66a2aeb7eed78a79fc781639'), ObjectId('66a2aeb7eed78a79fc78163a'), ObjectId('66a2aeb7eed78a79fc78163b'), ObjectId('66a2aeb7eed78a79fc78163c'), ObjectId('66a2aeb7eed78a79fc78163d'), ObjectId('66a2aeb7eed78a79fc78163e'), ObjectId('66a2aeb7eed78a79fc78163f'), ObjectId('66a2aeb7eed78a79fc781640'), ObjectId('66a2aeb7eed78a79fc781641'), ObjectId('66a2aeb7eed78a79fc781642'), ObjectId('66a2aeb7eed78a79fc781643'), ObjectId('66a2aeb7eed78a79fc781644'), ObjectId('66a2aeb7eed78a79fc781645'), ObjectId('66a2aeb7eed78a79fc781646'), ObjectId('66a2aeb7eed78a79fc781647'), ObjectId('66a2aeb7eed78a79fc781648'), ObjectId('66a2aeb7eed78a79fc781649'), ObjectId('66a2aeb7eed78a79fc78164a'), ObjectId('66a2aeb7eed78a79fc78164b'), ObjectId('66a2aeb7eed78a79fc78164c'), ObjectId('66a2aeb7eed78a79fc78164d'), ObjectId('66a2aeb7eed78a79fc78164e'), ObjectId('66a2aeb7eed78a79fc78164f'), ObjectId('66a2aeb7eed78a79fc781650'), ObjectId('66a2aeb7eed78a79fc781651'), ObjectId('66a2aeb7eed78a79fc781652'), ObjectId('66a2aeb7eed78a79fc781653'), ObjectId('66a2aeb7eed78a79fc781654'), ObjectId('66a2aeb7eed78a79fc781655'), ObjectId('66a2aeb7eed78a79fc781656'), ObjectId('66a2aeb7eed78a79fc781657'), ObjectId('66a2aeb7eed78a79fc781658'), ObjectId('66a2aeb7eed78a79fc781659'), ObjectId('66a2aeb7eed78a79fc78165a'), ObjectId('66a2aeb7eed78a79fc78165b'), ObjectId('66a2aeb7eed78a79fc78165c'), Ob